# %%
import asyncio
import pandas as pd 

from agents import Agent, Runner, function_tool
from agents import OpenAIChatCompletionsModel
from openai import AsyncOpenAI

import nflreadpy as nfl

# %%
player_stats = nfl.load_player_stats([2022, 2023])
player_stats = player_stats.to_pandas()
player_stats.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0022824       A.Lee            Andy Lee        P           SPEC
# 2  00-0023252     R.Gould        Robbie Gould        K           SPEC
# 3  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 4  00-0023853    M.Prater         Matt Prater        K           SPEC
#
#                                         headshot_url  season  week  \
# 0  https://static.www.nfl.com/image/private/f_aut...    2022     1
# 1  https://static.www.nfl.com/image/private/f_aut...    2022     1
# 2  https://static.www.nfl.com/image/private/f_aut...    2022     1
# 3  https://static.www.nfl.com/image/upload/f_auto...    2022     1
# 4  https://static.www.nfl.com/image/upload/f_auto...    2022     1
#
#   season_type team  ... pat_missed  pat_blocked  pat_pct  gwfg_made  gwfg_att  \
# ...

# %%
t_brady = player_stats[player_stats['player_name'] == 'T.Brady']
t_brady['player_id'].nunique()
# Out:
# 1

# %%
#player_stats['player_id'].nunique()
players = player_stats.groupby('player_id')['player_name']
players
